# %% [markdown]
# <a href="https://colab.research.google.com/github/LuTapia/git-tarea/blob/main/block1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#probando colaboratory en github

# %%
data(mtcars)
head(mtcars)
plot(mtcars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-083dce6ee76a> in <module>()
# ----> 1 data(mtcars)
#       2 head(mtcars)
#
# NameError: name 'data' is not defined
